# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilya-Svavilnyy/Python_course/blob/master/HomeWork10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI' : lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  human
# 2  robot
# 3  robot
# 4  human

# %%
pd.get_dummies(data['whoAmI'])
# Out:
#     human  robot
# 0       0      1
# 1       1      0
# 2       0      1
# 3       0      1
# 4       1      0
# 5       1      0
# 6       1      0
# 7       0      1
# 8       1      0
# 9       1      0
# 10      0      1
# 11      1      0
# 12      0      1
# 13      0      1
# 14      1      0
# 15      0      1
# 16      0      1
# 17      1      0
# 18      1      0
# 19      0      1

# %%
data['tmp'] = 1
data.set_index([data.index, 'whoAmI'], inplace=True)
data = data.unstack(level=-1, fill_value = 0).astype(int)
data.columns = data.columns.droplevel()
data.columns.name = None
print(data)
# Out:
#     human  robot
# 0       0      1
# 1       1      0
# 2       0      1
# 3       0      1
# 4       1      0
# 5       1      0
# 6       1      0
# 7       0      1
# 8       1      0
# 9       1      0
# 10      0      1
# 11      1      0
# 12      0      1
# 13      0      1
# 14      1      0
# 15      0      1
# 16      0      1
# 17      1      0
# 18      1      0
# 19      0      1
